# %%
# First we need to import the Pandas library
import pandas as pd

# We also import a plotting library
import matplotlib

# %% [markdown]
# # Which type of files can we read in Pandas?
#
# Pandas has built-in functionality to read and write different file formats:
#
#
# | Format Type | Data Description     | Reader         | Writer       |
# |-------------|----------------------|----------------|--------------|
# | text        | CSV                  | read_csv       | to_csv       |
# | text        | JSON                 | read_json      | to_json      |
# | text        | HTML                 | read_html      | to_html      |
# | text        | Local clipboard      | read_clipboard | to_clipboard |
# | binary      | MS Excel             | read_excel     | to_excel     |
# | binary      | HDF5 Format          | read_hdf       | to_hdf       |
# | binary      | Feather Format       | read_feather   | to_feather   |
# | binary      | Parquet Format       | read_parquet   | to_parquet   |
# | binary      | Msgpack              | read_msgpack   | to_msgpack   |
# | binary      | Stata                | read_stata     | to_stata     |
# | binary      | SAS                  | read_sas       |              |
# | binary      | Python Pickle Format | read_pickle    | to_pickle    |
# | SQL         | SQL                  | read_sql       | to_sql       |
# | SQL         | Google Big Query     | read_gbq       | to_gbq       |
#
#
#
# For BSP's purposes, the most common file extensions used are CSV, MS Excel and SQL.

# %% [markdown]
# # Exercise
#
# We will be working with the Volve dataset. This is an open dataset released by Equinor in 2018.
#
# Volve is a decommissioned field in the central part of the North Sea and was discovered in 1993, the plan for development and operation (PDO) was approved in 2005. The field was shut down in 2016 and the formal removal and decommissioning will be completed by the end of 2018.
#
# *The Volve Data was approved for data sharing in 2018 by the initiative of the last Operating company, Equinor and approved by the license partners ExxonMobil E&P Norway AS and Bayerngas Norge AS in the end of 2017.*

# %% [markdown]
# # Task 1. Import production data.
#
# ### Dataset:
#
# Link to Excel file:
#
# * Production Data: https://drive.google.com/uc?authuser=0&id=13IzgvJnM1sSDrtY_lAluck827fSTRUBi&export=download
# * Wellbore Codes:  https://drive.google.com/uc?authuser=0&id=1iqVFZeIhz-xDBZ3xuiKGxE-ZBlyGYumP&export=download
#
#
# ### Which type of files can we read in Pandas?
#
# Pandas has built-in functionality to read and write different file formats:
#
#
# | Format Type | Data Description     | Reader         | Writer       |
# |-------------|----------------------|----------------|--------------|
# | text        | CSV                  | read_csv       | to_csv       |
# | text        | JSON                 | read_json      | to_json      |
# | text        | HTML                 | read_html      | to_html      |
# | text        | Local clipboard      | read_clipboard | to_clipboard |
# | binary      | MS Excel             | read_excel     | to_excel     |
# | binary      | HDF5 Format          | read_hdf       | to_hdf       |
# | binary      | Feather Format       | read_feather   | to_feather   |
# | binary      | Parquet Format       | read_parquet   | to_parquet   |
# | binary      | Msgpack              | read_msgpack   | to_msgpack   |
# | binary      | Stata                | read_stata     | to_stata     |
# | binary      | SAS                  | read_sas       |              |
# | binary      | Python Pickle Format | read_pickle    | to_pickle    |
# | SQL         | SQL                  | read_sql       | to_sql       |
# | SQL         | Google Big Query     | read_gbq       | to_gbq       |
#
#
#
# For BSP's purposes, the most common file extensions used are CSV, MS Excel and SQL.

# %%
#Load the data (for wellbore and production)
prod = pd.read_excel("https://drive.google.com/uc?authuser=0&id=13IzgvJnM1sSDrtY_lAluck827fSTRUBi&export=download")
wellbore = pd.read_excel("https://drive.google.com/uc?authuser=0&id=1iqVFZeIhz-xDBZ3xuiKGxE-ZBlyGYumP&export=download")

# %%
#Check the first few lines of the production data
prod.columns, wellbore.columns
# Out:
# (Index(['Unnamed: 0', 'DATEPRD', 'NPD_WELL_BORE_CODE', 'NPD_FIELD_CODE',
#         'NPD_FIELD_NAME', 'NPD_FACILITY_CODE', 'NPD_FACILITY_NAME',
#         'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE',
#         'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P',
#         'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P', 'DP_CHOKE_SIZE',
#         'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL', 'BORE_WI_VOL',
#         'FLOW_KIND', 'WELL_TYPE'],
#        dtype='object'),
#  Index(['WELL_BORE_CODE', 'NPD_WELL_BORE_CODE'], dtype='object'))

# %%
#Check the first few lines of the well data
wellbore.columns
# Out:
# Index(['WELL_BORE_CODE', 'NPD_WELL_BORE_CODE'], dtype='object')

# %% [markdown]
# # Task 2:  How many rows and columns does the "Production Data" table has?

# %%
prod.shape, wellbore.shape
# Out:
# ((15634, 23), (7, 2))

# %% [markdown]
# # Task 3:  How many wells does the Volve field has?

# %%
prod["NPD_WELL_BORE_CODE"].nunique()
# Out:
# 7

# %% [markdown]
# # Task 4: Merge "Production Data" with "Wellbore Codes"

# %%
#First method - Pandas
merged = pd.merge(prod, wellbore, how='right', on='NPD_WELL_BORE_CODE')

# %% [markdown]
# # Task 5. Get unique well names

# %%
merged.columns
# Out:
# Index(['Unnamed: 0', 'DATEPRD', 'NPD_WELL_BORE_CODE', 'NPD_FIELD_CODE',
#        'NPD_FIELD_NAME', 'NPD_FACILITY_CODE', 'NPD_FACILITY_NAME',
#        'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE',
#        'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P',
#        'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P', 'DP_CHOKE_SIZE',
#        'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL', 'BORE_WI_VOL',
#        'FLOW_KIND', 'WELL_TYPE', 'WELL_BORE_CODE'],
#       dtype='object')

# %%
merged.WELL_BORE_CODE.unique()
# Out:
# array(['NO 15/9-F-1 C', 'NO 15/9-F-11 H', 'NO 15/9-F-12 H',
#        'NO 15/9-F-14 H', 'NO 15/9-F-15 D', 'NO 15/9-F-4 AH',
#        'NO 15/9-F-5 AH'], dtype=object)

# %%
merged[merged.WELL_BORE_CODE == 'NO 15/9-F-1 C']
# Out:
#      Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 0             0 2014-04-07  ...         WI   NO 15/9-F-1 C
# 1             1 2014-04-08  ...         OP   NO 15/9-F-1 C
# 2             2 2014-04-09  ...         OP   NO 15/9-F-1 C
# 3             3 2014-04-10  ...         OP   NO 15/9-F-1 C
# 4             4 2014-04-11  ...         OP   NO 15/9-F-1 C
# 5             5 2014-04-12  ...         OP   NO 15/9-F-1 C
# 6             6 2014-04-13  ...         OP   NO 15/9-F-1 C
# 7             7 2014-04-14  ...         OP   NO 15/9-F-1 C
# 8             8 2014-04-15  ...         OP   NO 15/9-F-1 C
# 9             9 2014-04-16  ...         OP   NO 15/9-F-1 C
# 10           10 2014-04-17  ...         OP   NO 15/9-F-1 C
# 11           11 2014-04-18  ...         OP   NO 15/9-F-1 C
# 12           12 2014-04-19  ...         OP   NO 15/9-F-1 C
# 13           13 2014-04-20  ...         OP   NO 15/9-F-1 C
# 14           14 2014-04-21  ...         OP   NO 15/9-F-1 C
# 15           15 2014-04-22  ...         OP   NO 15/9-F-1 C
# 16           16 2014-04-23  ...         OP   NO 15/9-F-1 C
# 17           17 2014-04-24  ...         OP   NO 15/9-F-1 C
# 18           18 2014-04-25  ...         OP   NO 15/9-F-1 C
# 19           19 2014-04-26  ...         OP   NO 15/9-F-1 C
# 20           20 2014-04-27  ...         OP   NO 15/9-F-1 C
# 21           21 2014-04-28  ...         OP   NO 15/9-F-1 C
# 22           22 2014-04-29  ...         OP   NO 15/9-F-1 C
# 23           23 2014-04-30  ...         OP   NO 15/9-F-1 C
# 24           24 2014-05-01  ...         OP   NO 15/9-F-1 C
# 25           25 2014-05-02  ...         OP   NO 15/9-F-1 C
# 26           26 2014-05-03  ...         OP   NO 15/9-F-1 C
# 27           27 2014-05-04  ...         OP   NO 15/9-F-1 C
# 28           28 2014-05-05  ...         OP   NO 15/9-F-1 C
# 29           29 2014-05-06  ...         OP   NO 15/9-F-1 C
# ..          ...        ...  ...        ...             ...
# 716         716 2016-03-23  ...         OP   NO 15/9-F-1 C
# 717         717 2016-03-24  ...         OP   NO 15/9-F-1 C
# 718         718 2016-03-25  ...         OP   NO 15/9-F-1 C
# 719         719 2016-03-26  ...         OP   NO 15/9-F-1 C
# 720         720 2016-03-27  ...         OP   NO 15/9-F-1 C
# 721         721 2016-03-28  ...         OP   NO 15/9-F-1 C
# 722         722 2016-03-29  ...         OP   NO 15/9-F-1 C
# 723         723 2016-03-30  ...         OP   NO 15/9-F-1 C
# 724         724 2016-03-31  ...         OP   NO 15/9-F-1 C
# 725         725 2016-04-01  ...         OP   NO 15/9-F-1 C
# 726         726 2016-04-02  ...         OP   NO 15/9-F-1 C
# 727         727 2016-04-03  ...         OP   NO 15/9-F-1 C
# 728         728 2016-04-04  ...         OP   NO 15/9-F-1 C
# 729         729 2016-04-05  ...         OP   NO 15/9-F-1 C
# 730         730 2016-04-06  ...         OP   NO 15/9-F-1 C
# 731         731 2016-04-07  ...         OP   NO 15/9-F-1 C
# 732         732 2016-04-08  ...         OP   NO 15/9-F-1 C
# 733         733 2016-04-09  ...         OP   NO 15/9-F-1 C
# 734         734 2016-04-10  ...         OP   NO 15/9-F-1 C
# 735         735 2016-04-11  ...         OP   NO 15/9-F-1 C
# 736         736 2016-04-12  ...         OP   NO 15/9-F-1 C
# 737         737 2016-04-13  ...         OP   NO 15/9-F-1 C
# 738         738 2016-04-14  ...         OP   NO 15/9-F-1 C
# 739         739 2016-04-15  ...         OP   NO 15/9-F-1 C
# 740         740 2016-04-16  ...         OP   NO 15/9-F-1 C
# 741         741 2016-04-17  ...         OP   NO 15/9-F-1 C
# 742         742 2016-04-18  ...         OP   NO 15/9-F-1 C
# 743         743 2016-04-19  ...         OP   NO 15/9-F-1 C
# 744         744 2016-04-20  ...         OP   NO 15/9-F-1 C
# 745         745 2016-04-21  ...         OP   NO 15/9-F-1 C
#
# [746 rows x 24 columns]

# %%
tmp = merged[merged.WELL_BORE_CODE == 'NO 15/9-F-1 C']
tmp.DATEPRD.min()
# Out:
# Timestamp('2014-04-07 00:00:00')

# %%
for well in merged.WELL_BORE_CODE.unique():
  tmp = merged[merged.WELL_BORE_CODE == well]
  print(f"Well {well} started on {tmp.DATEPRD.min()}")
# Out:
# Well NO 15/9-F-1 C started on 2014-04-07 00:00:00
# Well NO 15/9-F-11 H started on 2013-07-08 00:00:00
# Well NO 15/9-F-12 H started on 2008-02-12 00:00:00
# Well NO 15/9-F-14 H started on 2008-02-12 00:00:00
# Well NO 15/9-F-15 D started on 2014-01-12 00:00:00
# Well NO 15/9-F-4 AH started on 2007-09-01 00:00:00
# Well NO 15/9-F-5 AH started on 2007-09-01 00:00:00

# %%
for well in merged.WELL_BORE_CODE.unique():
  tmp = merged[merged.WELL_BORE_CODE == well]
  fstDate = tmp.DATEPRD.min()
  tmp2 = tmp[tmp.DATEPRD == fstDate]
  oil = tmp2.BORE_OIL_VOL.values[0]
  print(fstDate,oil)
# Out:
# 2014-04-07 00:00:00 0.0
# 2013-07-08 00:00:00 0.0
# 2008-02-12 00:00:00 284.65
# 2008-02-12 00:00:00 0.0
# 2014-01-12 00:00:00 0.0
# 2007-09-01 00:00:00 nan
# 2007-09-01 00:00:00 nan

# %% [markdown]
# # Task 6. Remove NaNs from Dataset

# %%
merged.dropna(subset=['AVG_DOWNHOLE_PRESSURE','AVG_DOWNHOLE_TEMPERATURE'])
# Out:
#       Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 0              0 2014-04-07  ...         WI   NO 15/9-F-1 C
# 4              4 2014-04-11  ...         OP   NO 15/9-F-1 C
# 5              5 2014-04-12  ...         OP   NO 15/9-F-1 C
# 6              6 2014-04-13  ...         OP   NO 15/9-F-1 C
# 7              7 2014-04-14  ...         OP   NO 15/9-F-1 C
# 8              8 2014-04-15  ...         OP   NO 15/9-F-1 C
# 9              9 2014-04-16  ...         OP   NO 15/9-F-1 C
# 10            10 2014-04-17  ...         OP   NO 15/9-F-1 C
# 11            11 2014-04-18  ...         OP   NO 15/9-F-1 C
# 12            12 2014-04-19  ...         OP   NO 15/9-F-1 C
# 13            13 2014-04-20  ...         OP   NO 15/9-F-1 C
# 14            14 2014-04-21  ...         OP   NO 15/9-F-1 C
# 15            15 2014-04-22  ...         OP   NO 15/9-F-1 C
# 16            16 2014-04-23  ...         OP   NO 15/9-F-1 C
# 17            17 2014-04-24  ...         OP   NO 15/9-F-1 C
# 18            18 2014-04-25  ...         OP   NO 15/9-F-1 C
# 19            19 2014-04-26  ...         OP   NO 15/9-F-1 C
# 20            20 2014-04-27  ...         OP   NO 15/9-F-1 C
# 21            21 2014-04-28  ...         OP   NO 15/9-F-1 C
# 22            22 2014-04-29  ...         OP   NO 15/9-F-1 C
# 23            23 2014-04-30  ...         OP   NO 15/9-F-1 C
# 24            24 2014-05-01  ...         OP   NO 15/9-F-1 C
# 25            25 2014-05-02  ...         OP   NO 15/9-F-1 C
# 26            26 2014-05-03  ...         OP   NO 15/9-F-1 C
# 27            27 2014-05-04  ...         OP   NO 15/9-F-1 C
# 28            28 2014-05-05  ...         OP   NO 15/9-F-1 C
# 29            29 2014-05-06  ...         OP   NO 15/9-F-1 C
# 30            30 2014-05-07  ...         OP   NO 15/9-F-1 C
# 31            31 2014-05-08  ...         OP   NO 15/9-F-1 C
# 32            32 2014-05-09  ...         OP   NO 15/9-F-1 C
# ...          ...        ...  ...        ...             ...
# 8971        8971 2016-08-19  ...         OP  NO 15/9-F-15 D
# 8972        8972 2016-08-20  ...         OP  NO 15/9-F-15 D
# 8973        8973 2016-08-21  ...         OP  NO 15/9-F-15 D
# 8974        8974 2016-08-22  ...         OP  NO 15/9-F-15 D
# 8975        8975 2016-08-23  ...         OP  NO 15/9-F-15 D
# 8976        8976 2016-08-24  ...         OP  NO 15/9-F-15 D
# 8977        8977 2016-08-25  ...         OP  NO 15/9-F-15 D
# 8978        8978 2016-08-26  ...         OP  NO 15/9-F-15 D
# 8979        8979 2016-08-27  ...         OP  NO 15/9-F-15 D
# 8980        8980 2016-08-28  ...         OP  NO 15/9-F-15 D
# 8981        8981 2016-08-29  ...         OP  NO 15/9-F-15 D
# 8982        8982 2016-08-30  ...         OP  NO 15/9-F-15 D
# 8983        8983 2016-08-31  ...         OP  NO 15/9-F-15 D
# 8984        8984 2016-09-01  ...         OP  NO 15/9-F-15 D
# 8985        8985 2016-09-02  ...         OP  NO 15/9-F-15 D
# 8986        8986 2016-09-03  ...         OP  NO 15/9-F-15 D
# 8987        8987 2016-09-04  ...         OP  NO 15/9-F-15 D
# 8988        8988 2016-09-05  ...         OP  NO 15/9-F-15 D
# 8989        8989 2016-09-06  ...         OP  NO 15/9-F-15 D
# 8990        8990 2016-09-07  ...         OP  NO 15/9-F-15 D
# 8991        8991 2016-09-08  ...         OP  NO 15/9-F-15 D
# 8992        8992 2016-09-09  ...         OP  NO 15/9-F-15 D
# 8993        8993 2016-09-10  ...         OP  NO 15/9-F-15 D
# 8994        8994 2016-09-11  ...         OP  NO 15/9-F-15 D
# 8995        8995 2016-09-12  ...         OP  NO 15/9-F-15 D
# 8996        8996 2016-09-13  ...         OP  NO 15/9-F-15 D
# 8997        8997 2016-09-14  ...         OP  NO 15/9-F-15 D
# 8998        8998 2016-09-15  ...         OP  NO 15/9-F-15 D
# 8999        8999 2016-09-16  ...         OP  NO 15/9-F-15 D
# 9000        9000 2016-09-17  ...         OP  NO 15/9-F-15 D
#
# [8980 rows x 24 columns]

# %% [markdown]
# # Task 7. Remove NaNs from BORE_WI_VOL column

# %%
merged.fillna(value = 0, inplace=True)

# %%
# ?prod['BORE_OIL_VOL'].dropna()

# %% [markdown]
# # Task 8. Create a new DataFrame containing only only producing wells.

# %%
'''
This code is for creating a dataframe
It works with Merge
'''
merged.WELL_TYPE.unique()
# Out:
# array(['WI', 'OP'], dtype=object)

# %%
producers = merged[merged.WELL_TYPE=='OP']

# %% [markdown]
# # Task 9. Select columns "DATEPRD", "BORE_OIL_VOL" and "BORE_GAS_VOL'" for well NO 15/9-F-1 C

# %%
producers.columns
# Out:
# Index(['Unnamed: 0', 'DATEPRD', 'NPD_WELL_BORE_CODE', 'NPD_FIELD_CODE',
#        'NPD_FIELD_NAME', 'NPD_FACILITY_CODE', 'NPD_FACILITY_NAME',
#        'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE',
#        'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P',
#        'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P', 'DP_CHOKE_SIZE',
#        'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL', 'BORE_WI_VOL',
#        'FLOW_KIND', 'WELL_TYPE', 'WELL_BORE_CODE'],
#       dtype='object')

# %%
colsToKeep = ['DATEPRD','WELL_BORE_CODE']
producers[colsToKeep]
# Out:
#          DATEPRD  WELL_BORE_CODE
# 1     2014-04-08   NO 15/9-F-1 C
# 2     2014-04-09   NO 15/9-F-1 C
# 3     2014-04-10   NO 15/9-F-1 C
# 4     2014-04-11   NO 15/9-F-1 C
# 5     2014-04-12   NO 15/9-F-1 C
# 6     2014-04-13   NO 15/9-F-1 C
# 7     2014-04-14   NO 15/9-F-1 C
# 8     2014-04-15   NO 15/9-F-1 C
# 9     2014-04-16   NO 15/9-F-1 C
# 10    2014-04-17   NO 15/9-F-1 C
# 11    2014-04-18   NO 15/9-F-1 C
# 12    2014-04-19   NO 15/9-F-1 C
# 13    2014-04-20   NO 15/9-F-1 C
# 14    2014-04-21   NO 15/9-F-1 C
# 15    2014-04-22   NO 15/9-F-1 C
# 16    2014-04-23   NO 15/9-F-1 C
# 17    2014-04-24   NO 15/9-F-1 C
# 18    2014-04-25   NO 15/9-F-1 C
# 19    2014-04-26   NO 15/9-F-1 C
# 20    2014-04-27   NO 15/9-F-1 C
# 21    2014-04-28   NO 15/9-F-1 C
# 22    2014-04-29   NO 15/9-F-1 C
# 23    2014-04-30   NO 15/9-F-1 C
# 24    2014-05-01   NO 15/9-F-1 C
# 25    2014-05-02   NO 15/9-F-1 C
# 26    2014-05-03   NO 15/9-F-1 C
# 27    2014-05-04   NO 15/9-F-1 C
# 28    2014-05-05   NO 15/9-F-1 C
# 29    2014-05-06   NO 15/9-F-1 C
# 30    2014-05-07   NO 15/9-F-1 C
# ...          ...             ...
# 15596 2016-08-12  NO 15/9-F-5 AH
# 15597 2016-08-13  NO 15/9-F-5 AH
# 15598 2016-08-14  NO 15/9-F-5 AH
# 15599 2016-08-15  NO 15/9-F-5 AH
# 15600 2016-08-16  NO 15/9-F-5 AH
# 15601 2016-08-17  NO 15/9-F-5 AH
# 15602 2016-08-18  NO 15/9-F-5 AH
# 15603 2016-08-19  NO 15/9-F-5 AH
# 15604 2016-08-20  NO 15/9-F-5 AH
# 15605 2016-08-21  NO 15/9-F-5 AH
# 15606 2016-08-22  NO 15/9-F-5 AH
# 15607 2016-08-23  NO 15/9-F-5 AH
# 15608 2016-08-24  NO 15/9-F-5 AH
# 15609 2016-08-25  NO 15/9-F-5 AH
# 15610 2016-08-26  NO 15/9-F-5 AH
# 15611 2016-08-27  NO 15/9-F-5 AH
# 15612 2016-08-28  NO 15/9-F-5 AH
# 15613 2016-08-29  NO 15/9-F-5 AH
# 15614 2016-08-30  NO 15/9-F-5 AH
# 15615 2016-08-31  NO 15/9-F-5 AH
# 15616 2016-09-01  NO 15/9-F-5 AH
# 15617 2016-09-02  NO 15/9-F-5 AH
# 15618 2016-09-03  NO 15/9-F-5 AH
# 15619 2016-09-04  NO 15/9-F-5 AH
# 15620 2016-09-05  NO 15/9-F-5 AH
# 15628 2016-09-13  NO 15/9-F-5 AH
# 15629 2016-09-14  NO 15/9-F-5 AH
# 15630 2016-09-15  NO 15/9-F-5 AH
# 15631 2016-09-16  NO 15/9-F-5 AH
# 15632 2016-09-17  NO 15/9-F-5 AH
#
# [9143 rows x 2 columns]

# %% [markdown]
# # Task 10. Plot Oil and Gas production vs Time for Well NO 15/9-F-1 C

# %% [markdown]
# # Task 11. Plot Oil production vs Time for all Producing wells in Volve

# %% [markdown]
# # Task 12. Plot Water injection vs Time for all Injectors in Volve

# %% [markdown]
# # Task 13. Plot Total Production Rate and Total Injection vs Time for Volve

# %% [markdown]
# # Task 14. Calculate the Cumulative Oil Production for the Field  Plot results.
