# %%
# First we need to import the Pandas library
import pandas as pd

# We also import a plotting library
# ?pd.read_csv

# %% [markdown]
# # Which type of files can we read in Pandas?
#
# Pandas has built-in functionality to read and write different file formats:
#
#
# | Format Type | Data Description     | Reader         | Writer       |
# |-------------|----------------------|----------------|--------------|
# | text        | CSV                  | read_csv       | to_csv       |
# | text        | JSON                 | read_json      | to_json      |
# | text        | HTML                 | read_html      | to_html      |
# | text        | Local clipboard      | read_clipboard | to_clipboard |
# | binary      | MS Excel             | read_excel     | to_excel     |
# | binary      | HDF5 Format          | read_hdf       | to_hdf       |
# | binary      | Feather Format       | read_feather   | to_feather   |
# | binary      | Parquet Format       | read_parquet   | to_parquet   |
# | binary      | Msgpack              | read_msgpack   | to_msgpack   |
# | binary      | Stata                | read_stata     | to_stata     |
# | binary      | SAS                  | read_sas       |              |
# | binary      | Python Pickle Format | read_pickle    | to_pickle    |
# | SQL         | SQL                  | read_sql       | to_sql       |
# | SQL         | Google Big Query     | read_gbq       | to_gbq       |
#
#
#
# For BSP's purposes, the most common file extensions used are CSV, MS Excel and SQL.

# %% [markdown]
# # Exercise
#
# We will be working with the Volve dataset. This is an open dataset released by Equinor in 2018.
#
# Volve is a decommissioned field in the central part of the North Sea and was discovered in 1993, the plan for development and operation (PDO) was approved in 2005. The field was shut down in 2016 and the formal removal and decommissioning will be completed by the end of 2018.
#
# *The Volve Data was approved for data sharing in 2018 by the initiative of the last Operating company, Equinor and approved by the license partners ExxonMobil E&P Norway AS and Bayerngas Norge AS in the end of 2017.*

# %% [markdown]
# # Task 1. Import production data.
#
# ### Dataset:
#
# Link to Excel file:
#
# * Production Data: https://drive.google.com/uc?authuser=0&id=13IzgvJnM1sSDrtY_lAluck827fSTRUBi&export=download
# * Wellbore Codes:  https://drive.google.com/uc?authuser=0&id=1iqVFZeIhz-xDBZ3xuiKGxE-ZBlyGYumP&export=download
#
#
# ### Which type of files can we read in Pandas?
#
# Pandas has built-in functionality to read and write different file formats:
#
#
# | Format Type | Data Description     | Reader         | Writer       |
# |-------------|----------------------|----------------|--------------|
# | text        | CSV                  | read_csv       | to_csv       |
# | text        | JSON                 | read_json      | to_json      |
# | text        | HTML                 | read_html      | to_html      |
# | text        | Local clipboard      | read_clipboard | to_clipboard |
# | binary      | MS Excel             | read_excel     | to_excel     |
# | binary      | HDF5 Format          | read_hdf       | to_hdf       |
# | binary      | Feather Format       | read_feather   | to_feather   |
# | binary      | Parquet Format       | read_parquet   | to_parquet   |
# | binary      | Msgpack              | read_msgpack   | to_msgpack   |
# | binary      | Stata                | read_stata     | to_stata     |
# | binary      | SAS                  | read_sas       |              |
# | binary      | Python Pickle Format | read_pickle    | to_pickle    |
# | SQL         | SQL                  | read_sql       | to_sql       |
# | SQL         | Google Big Query     | read_gbq       | to_gbq       |
#
#
#
# For BSP's purposes, the most common file extensions used are CSV, MS Excel and SQL.

# %%
#Load the data (for wellbore and production)
import pandas as pd
prod=pd.read_excel("https://drive.google.com/uc?authuser=0&id=13IzgvJnM1sSDrtY_lAluck827fSTRUBi&export=download")
prod

wellb=pd.read_excel("https://drive.google.com/uc?authuser=0&id=1iqVFZeIhz-xDBZ3xuiKGxE-ZBlyGYumP&export=download")
wellb
# Out:
#    WELL_BORE_CODE  NPD_WELL_BORE_CODE
# 0   NO 15/9-F-1 C                7405
# 1  NO 15/9-F-11 H                7078
# 2  NO 15/9-F-12 H                5599
# 3  NO 15/9-F-14 H                5351
# 4  NO 15/9-F-15 D                7289
# 5  NO 15/9-F-4 AH                5693
# 6  NO 15/9-F-5 AH                5769

# %%
#Check the first few lines of the production data
wellb.head(6)
# Out:
#    WELL_BORE_CODE  NPD_WELL_BORE_CODE
# 0   NO 15/9-F-1 C                7405
# 1  NO 15/9-F-11 H                7078
# 2  NO 15/9-F-12 H                5599
# 3  NO 15/9-F-14 H                5351
# 4  NO 15/9-F-15 D                7289
# 5  NO 15/9-F-4 AH                5693

# %%
#Check the first few lines of the well data
prod.head(5)
# Out:
#    Unnamed: 0    DATEPRD  NPD_WELL_BORE_CODE  ...  BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0           0 2014-04-07                7405  ...          NaN  production         WI
# 1           1 2014-04-08                7405  ...          NaN  production         OP
# 2           2 2014-04-09                7405  ...          NaN  production         OP
# 3           3 2014-04-10                7405  ...          NaN  production         OP
# 4           4 2014-04-11                7405  ...          NaN  production         OP
#
# [5 rows x 23 columns]

# %% [markdown]
# # Task 2:  How many rows and columns does the "Production Data" table has?

# %%
prod.shape
# Out:
# (15634, 23)

# %% [markdown]
# # Task 3:  How many wells does the Volve field has?

# %% [markdown]
# prod.columns

# %%
wellb.columns
# Out:
# Index(['WELL_BORE_CODE', 'NPD_WELL_BORE_CODE'], dtype='object')

# %%
prod.columns
# Out:
# Index(['Unnamed: 0', 'DATEPRD', 'NPD_WELL_BORE_CODE', 'NPD_FIELD_CODE',
#        'NPD_FIELD_NAME', 'NPD_FACILITY_CODE', 'NPD_FACILITY_NAME',
#        'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE',
#        'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P',
#        'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P', 'DP_CHOKE_SIZE',
#        'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL', 'BORE_WI_VOL',
#        'FLOW_KIND', 'WELL_TYPE'],
#       dtype='object')

# %% [markdown]
# # Task 4: Merge "Production Data" with "Wellbore Codes"

# %%
merge_columns=pd.merge(prod,wellb, left_on='NPD_WELL_BORE_CODE',right_on='NPD_WELL_BORE_CODE')
merge_columns.head(10)
# Out:
#    Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 0           0 2014-04-07  ...         WI   NO 15/9-F-1 C
# 1           1 2014-04-08  ...         OP   NO 15/9-F-1 C
# 2           2 2014-04-09  ...         OP   NO 15/9-F-1 C
# 3           3 2014-04-10  ...         OP   NO 15/9-F-1 C
# 4           4 2014-04-11  ...         OP   NO 15/9-F-1 C
# 5           5 2014-04-12  ...         OP   NO 15/9-F-1 C
# 6           6 2014-04-13  ...         OP   NO 15/9-F-1 C
# 7           7 2014-04-14  ...         OP   NO 15/9-F-1 C
# 8           8 2014-04-15  ...         OP   NO 15/9-F-1 C
# 9           9 2014-04-16  ...         OP   NO 15/9-F-1 C
#
# [10 rows x 24 columns]

# %% [markdown]
# # Task 5. Get unique well names and print something like "Well 1 is DDDDD"

# %%
w1 = wellb["WELL_BORE_CODE"].unique()

id = 1
for i in w1:
  print(f"Well {id} is {i}")
  id+=1
# Out:
# Well 1 is NO 15/9-F-1 C
# Well 2 is NO 15/9-F-11 H
# Well 3 is NO 15/9-F-12 H
# Well 4 is NO 15/9-F-14 H
# Well 5 is NO 15/9-F-15 D
# Well 6 is NO 15/9-F-4 AH
# Well 7 is NO 15/9-F-5 AH

# %%
w1
# Out:
# array(['NO 15/9-F-1 C', 'NO 15/9-F-11 H', 'NO 15/9-F-12 H',
#        'NO 15/9-F-14 H', 'NO 15/9-F-15 D', 'NO 15/9-F-4 AH',
#        'NO 15/9-F-5 AH'], dtype=object)

# %% [markdown]
# # Task 6. Remove NaNs from Dataset

# %%
merge_columns.head(3)
# Out:
#    Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 0           0 2014-04-07  ...         WI   NO 15/9-F-1 C
# 1           1 2014-04-08  ...         OP   NO 15/9-F-1 C
# 2           2 2014-04-09  ...         OP   NO 15/9-F-1 C
#
# [3 rows x 24 columns]

# %%
merge_columns.dropna(subset=["BORE_WI_VOL","BORE_OIL_VOL","BORE_GAS_VOL"], inplace=True)

# %%
merge_columns
# Out:
#        Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 15496       15496 2016-05-04  ...         WI  NO 15/9-F-5 AH
# 15579       15579 2016-07-26  ...         WI  NO 15/9-F-5 AH
# 15580       15580 2016-07-27  ...         WI  NO 15/9-F-5 AH
# 15581       15581 2016-07-28  ...         WI  NO 15/9-F-5 AH
# 15582       15582 2016-07-29  ...         WI  NO 15/9-F-5 AH
# 15583       15583 2016-07-30  ...         WI  NO 15/9-F-5 AH
# 15584       15584 2016-07-31  ...         WI  NO 15/9-F-5 AH
# 15585       15585 2016-08-01  ...         WI  NO 15/9-F-5 AH
# 15621       15621 2016-09-06  ...         WI  NO 15/9-F-5 AH
# 15622       15622 2016-09-07  ...         WI  NO 15/9-F-5 AH
# 15623       15623 2016-09-08  ...         WI  NO 15/9-F-5 AH
# 15624       15624 2016-09-09  ...         WI  NO 15/9-F-5 AH
# 15625       15625 2016-09-10  ...         WI  NO 15/9-F-5 AH
# 15626       15626 2016-09-11  ...         WI  NO 15/9-F-5 AH
# 15627       15627 2016-09-12  ...         WI  NO 15/9-F-5 AH
#
# [15 rows x 24 columns]

# %% [markdown]
# # Task 7. Remove NaNs from BORE_WI_VOL column

# %% [markdown]
# # Task 8. Create a new DataFrame containing only only producing wells.

# %%
merge_columns.head()
# Out:
#    Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 0           0 2014-04-07  ...         WI   NO 15/9-F-1 C
# 1           1 2014-04-08  ...         OP   NO 15/9-F-1 C
# 2           2 2014-04-09  ...         OP   NO 15/9-F-1 C
# 3           3 2014-04-10  ...         OP   NO 15/9-F-1 C
# 4           4 2014-04-11  ...         OP   NO 15/9-F-1 C
#
# [5 rows x 24 columns]

# %%
merge_columns["WELL_TYPE"].unique()
# Out:
# array(['WI', 'OP'], dtype=object)

# %%
merge_columns.columns
# Out:
# Index(['Unnamed: 0', 'DATEPRD', 'NPD_WELL_BORE_CODE', 'NPD_FIELD_CODE',
#        'NPD_FIELD_NAME', 'NPD_FACILITY_CODE', 'NPD_FACILITY_NAME',
#        'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE',
#        'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P',
#        'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P', 'DP_CHOKE_SIZE',
#        'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL', 'BORE_WI_VOL',
#        'FLOW_KIND', 'WELL_TYPE', 'WELL_BORE_CODE'],
#       dtype='object')

# %%
result = merge_columns.loc[merge_columns['WELL_TYPE'] == 'OP']

result['WELL_TYPE'].unique()
# Out:
# array(['OP'], dtype=object)

# %%
result
# Out:
#        Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 1               1 2014-04-08  ...         OP   NO 15/9-F-1 C
# 2               2 2014-04-09  ...         OP   NO 15/9-F-1 C
# 3               3 2014-04-10  ...         OP   NO 15/9-F-1 C
# 4               4 2014-04-11  ...         OP   NO 15/9-F-1 C
# 5               5 2014-04-12  ...         OP   NO 15/9-F-1 C
# 6               6 2014-04-13  ...         OP   NO 15/9-F-1 C
# 7               7 2014-04-14  ...         OP   NO 15/9-F-1 C
# 8               8 2014-04-15  ...         OP   NO 15/9-F-1 C
# 9               9 2014-04-16  ...         OP   NO 15/9-F-1 C
# 10             10 2014-04-17  ...         OP   NO 15/9-F-1 C
# 11             11 2014-04-18  ...         OP   NO 15/9-F-1 C
# 12             12 2014-04-19  ...         OP   NO 15/9-F-1 C
# 13             13 2014-04-20  ...         OP   NO 15/9-F-1 C
# 14             14 2014-04-21  ...         OP   NO 15/9-F-1 C
# 15             15 2014-04-22  ...         OP   NO 15/9-F-1 C
# 16             16 2014-04-23  ...         OP   NO 15/9-F-1 C
# 17             17 2014-04-24  ...         OP   NO 15/9-F-1 C
# 18             18 2014-04-25  ...         OP   NO 15/9-F-1 C
# 19             19 2014-04-26  ...         OP   NO 15/9-F-1 C
# 20             20 2014-04-27  ...         OP   NO 15/9-F-1 C
# 21             21 2014-04-28  ...         OP   NO 15/9-F-1 C
# 22             22 2014-04-29  ...         OP   NO 15/9-F-1 C
# 23             23 2014-04-30  ...         OP   NO 15/9-F-1 C
# 24             24 2014-05-01  ...         OP   NO 15/9-F-1 C
# 25             25 2014-05-02  ...         OP   NO 15/9-F-1 C
# 26             26 2014-05-03  ...         OP   NO 15/9-F-1 C
# 27             27 2014-05-04  ...         OP   NO 15/9-F-1 C
# 28             28 2014-05-05  ...         OP   NO 15/9-F-1 C
# 29             29 2014-05-06  ...         OP   NO 15/9-F-1 C
# 30             30 2014-05-07  ...         OP   NO 15/9-F-1 C
# ...           ...        ...  ...        ...             ...
# 15596       15596 2016-08-12  ...         OP  NO 15/9-F-5 AH
# 15597       15597 2016-08-13  ...         OP  NO 15/9-F-5 AH
# 15598       15598 2016-08-14  ...         OP  NO 15/9-F-5 AH
# 15599       15599 2016-08-15  ...         OP  NO 15/9-F-5 AH
# 15600       15600 2016-08-16  ...         OP  NO 15/9-F-5 AH
# 15601       15601 2016-08-17  ...         OP  NO 15/9-F-5 AH
# 15602       15602 2016-08-18  ...         OP  NO 15/9-F-5 AH
# 15603       15603 2016-08-19  ...         OP  NO 15/9-F-5 AH
# 15604       15604 2016-08-20  ...         OP  NO 15/9-F-5 AH
# 15605       15605 2016-08-21  ...         OP  NO 15/9-F-5 AH
# 15606       15606 2016-08-22  ...         OP  NO 15/9-F-5 AH
# 15607       15607 2016-08-23  ...         OP  NO 15/9-F-5 AH
# 15608       15608 2016-08-24  ...         OP  NO 15/9-F-5 AH
# 15609       15609 2016-08-25  ...         OP  NO 15/9-F-5 AH
# 15610       15610 2016-08-26  ...         OP  NO 15/9-F-5 AH
# 15611       15611 2016-08-27  ...         OP  NO 15/9-F-5 AH
# 15612       15612 2016-08-28  ...         OP  NO 15/9-F-5 AH
# 15613       15613 2016-08-29  ...         OP  NO 15/9-F-5 AH
# 15614       15614 2016-08-30  ...         OP  NO 15/9-F-5 AH
# 15615       15615 2016-08-31  ...         OP  NO 15/9-F-5 AH
# 15616       15616 2016-09-01  ...         OP  NO 15/9-F-5 AH
# 15617       15617 2016-09-02  ...         OP  NO 15/9-F-5 AH
# 15618       15618 2016-09-03  ...         OP  NO 15/9-F-5 AH
# 15619       15619 2016-09-04  ...         OP  NO 15/9-F-5 AH
# 15620       15620 2016-09-05  ...         OP  NO 15/9-F-5 AH
# 15628       15628 2016-09-13  ...         OP  NO 15/9-F-5 AH
# 15629       15629 2016-09-14  ...         OP  NO 15/9-F-5 AH
# 15630       15630 2016-09-15  ...         OP  NO 15/9-F-5 AH
# 15631       15631 2016-09-16  ...         OP  NO 15/9-F-5 AH
# 15632       15632 2016-09-17  ...         OP  NO 15/9-F-5 AH
#
# [9143 rows x 24 columns]

# %%
# merge_columns[merge_columns['WELL_TYPE']=='OP']

# %% [markdown]
# # Task 9. Select columns "DATEPRD", "BORE_OIL_VOL" and "BORE_GAS_VOL'" for well NO 15/9-F-1 C

# %%
well1 = result[result['WELL_BORE_CODE'] == 'NO 15/9-F-1 C']
result.head()
# Out:
#    Unnamed: 0    DATEPRD  ...  WELL_TYPE  WELL_BORE_CODE
# 1           1 2014-04-08  ...         OP   NO 15/9-F-1 C
# 2           2 2014-04-09  ...         OP   NO 15/9-F-1 C
# 3           3 2014-04-10  ...         OP   NO 15/9-F-1 C
# 4           4 2014-04-11  ...         OP   NO 15/9-F-1 C
# 5           5 2014-04-12  ...         OP   NO 15/9-F-1 C
#
# [5 rows x 24 columns]

# %%
cols = ['DATEPRD','BORE_OIL_VOL','BORE_GAS_VOL']
df1 = merge_columns[cols]
df1
# Out:
#          DATEPRD  BORE_OIL_VOL  BORE_GAS_VOL
# 15496 2016-05-04        328.70      52387.43
# 15579 2016-07-26        340.52      54468.73
# 15580 2016-07-27        334.18      53468.31
# 15581 2016-07-28        338.69      54190.20
# 15582 2016-07-29        342.77      53787.03
# 15583 2016-07-30        349.25      55339.69
# 15584 2016-07-31        342.39      53103.90
# 15585 2016-08-01        351.38      53406.08
# 15621 2016-09-06          0.00          0.00
# 15622 2016-09-07          0.00          0.00
# 15623 2016-09-08          0.00          0.00
# 15624 2016-09-09          0.00          0.00
# 15625 2016-09-10          0.00          0.00
# 15626 2016-09-11          0.00          0.00
# 15627 2016-09-12          0.00          0.00

# %% [markdown]
# # Task 10. Plot Oil and Gas production vs Time for Well NO 15/9-F-1 C

# %%
welllist = result.WELL_BORE_CODE.unique()

# %%
count = 1
for well in welllist:
  temp = result[result['WELL_BORE_CODE'] == well]
  #Figure
  figure = plt.figure(figsize = (10,5))

  #plot
  plt.plot(temp.DATEPRD,temp.BORE_GAS_VOL, 'g-')

  #Legend
  plt.legend()

  ##title
  plt.title(well)
  
  
  #save
  plt.savefig(f"{count}.png")
  
  count+=1

# %%
import matplotlib.pyplot as plt

#Figure
figure = plt.figure(figsize = (10,5))

#plot
plt.plot(well1.DATEPRD,well1.BORE_OIL_VOL, 'r-')

#Legend
plt.legend()

##title
plt.title("well 15/9-F-1 C ")

#save
plt.show()

# %% [markdown]
# # Task 11. Plot Oil production vs Time for all Producing wells in Volve

# %% [markdown]
# # Task 12. Plot Water injection vs Time for all Injectors in Volve

# %% [markdown]
# # Task 13. Plot Total Production Rate and Total Injection vs Time for Volve

# %% [markdown]
# # Task 14. Calculate the Cumulative Oil Production for the Field  Plot results.
